# %%
#solution 1

import queue
class Graph:
    def __init__(self, nVerticies):
        self.nVerticies = nVerticies
        self.adjMatrix = [ [0 for i in range(nVerticies)] for j in range(nVerticies)]
        
        
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
        
    def removeEdge(self, v1, v2):
        if self.containsEdge(v1, v2) is False:
            return
        self.adjMatrix[v1][v2] = 0
        self.adjMatrix[v2][v1] = 0
        
    
    def containsEdge(self, v1, v2):
        return True if self.adjMatrix[v1][v2] > 0 else False
    
    
    def __str__(self):
        return str(self.adjMatrix)
            
    
    def __getPathHelper(self, v1, v2,l, visited):
        
        visited[v1] = True
        if v1 == v2:
            l.append(v2)
            return l
            
        
        for i in range(self.nVerticies):
            if self.adjMatrix[v1][i] == 1 and visited[i] is False:
                pathFound = self.__getPathHelper(i, v2,l, visited)
                if pathFound:
                    pathFound.append(v1)
                    return pathFound
        return
                
    
    def getPath(self, v1, v2):
        visited = [False for i in range(self.nVerticies)]
        for i in range(self.nVerticies):
            if visited[i] is False:
                k = self.__getPathHelper(v1, v2,[], visited)
                if k:
                    print(*k)
                    return
                

                
V, E = [int(i) for i in input().split()]
g = Graph(V)
for i in range(E):
    v1, v2 = [int(i) for i in input().split()]
    g.addEdge(v1, v2)
    
v1, v2 = [int(i) for i in input().split()]
g.getPath(v1, v2)
# Out:
# 3 2
# 0 1
# 0 2
# 0 2
# 2 0

# %%
#solution 2
import queue
class Graph:
    def __init__(self, nVerticies):
        self.nVerticies = nVerticies
        self.adjMatrix = [ [0 for i in range(nVerticies)] for j in range(nVerticies)]
        
        
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
        
    def removeEdge(self, v1, v2):
        if self.containsEdge(v1, v2) is False:
            return
        self.adjMatrix[v1][v2] = 0
        self.adjMatrix[v2][v1] = 0
        
    
    def containsEdge(self, v1, v2):
        return True if self.adjMatrix[v1][v2] > 0 else False
    
    
    def __str__(self):
        return str(self.adjMatrix)
            
    
    def __getPathHelper(self, v1, v2, visited):
        
        visited[v1] = True
        for i in range(self.nVerticies):
            if i == v2 and self.adjMatrix[v1][i] == 1:
                return [v2, v1]
            
        
        for i in range(self.nVerticies):
            if self.adjMatrix[v1][i] == 1 and visited[i] is False:
                pathFound = self.__getPathHelper(i, v2, visited)
                if pathFound:
                    pathFound.append(v1)
                    return pathFound
                
    
    def getPath(self, v1, v2):
        visited = [False for i in range(self.nVerticies)]
        if v1 == v2:
            print(v1)
            return
        else:
            for i in range(self.nVerticies):
                if visited[i] is False:
                    k = self.__getPathHelper(v1, v2, visited)
                    if k:
                        print(*k)
                        return
                
V, E = [int(i) for i in input().split()]
g = Graph(V)
for i in range(E):
    v1, v2 = [int(i) for i in input().split()]
    g.addEdge(v1, v2)
    
v1, v2 = [int(i) for i in input().split()]
g.getPath(v1, v2)
