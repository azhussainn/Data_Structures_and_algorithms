# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


def takeLevelWiseTreeInput():
    
    q = queue.Queue()
    print("Enter Root")
    rootData = int(input())
    
    if rootData == -1:
        return None
    
    root = BinaryTreeNode(rootData)
    q.put(root)
    
    while not(q.empty()):
        
        currentNode = q.get()
        print("Enter the left child of: ",currentNode.data)
        leftChildData = int(input())
        
        if leftChildData != -1:
            leftChild = BinaryTreeNode(leftChildData)
            currentNode.left = leftChild
            q.put(leftChild)
            
            
        print("Enter the right child of: ",currentNode.data)
        rightChildData = int(input())
        
        if rightChildData != -1:
            rightChild = BinaryTreeNode(rightChildData)
            currentNode.right = rightChild
            q.put(rightChild)
            
    return root


def printTreeDetailed(root):
    if root == None:
        return
    
    
    print(root.data, end = ': ')
    
    if root.left != None:
        print("L:", root.left.data, end = ':')
        
        
    if root.right != None:
        print("R:", root.right.data, end = "")
    
    print()
    printTreeDetailed(root.left)
    printTreeDetailed(root.right)

# %%
def isBst(root, minRange, maxRange):
    
    if root == None:
        return True
    
    if root.data < minRange or root.data > maxRange:
        return False
        
    isLeftInRange = isBst(root.left, minRange, root.data -1)
    isRighInRange = isBst(root.right, root.data, maxRange)

    return isLeftInRange and isRighInRange

# %%
root = takeLevelWiseTreeInput()
printTreeDetailed(root)
print()
minRange = -1000000000000
maxRange =  1000000000000
print(isBst(root, minRange, maxRange))
# Out:
# Enter Root
# 4
# Enter the left child of:  4
# 2
# Enter the right child of:  4
# 6
# Enter the left child of:  2
# 1
# Enter the right child of:  2
# 30
# Enter the left child of:  6
# 5
# Enter the right child of:  6
# 7
# Enter the left child of:  1
# -1
# Enter the right child of:  1
# -1
# Enter the left child of:  30
# -1
# Enter the right child of:  30
# -1
# Enter the left child of:  5
# -1
# Enter the right child of:  5
# -1
# Enter the left child of:  7
# -1
# Enter the right child of:  7
# -1
# 4: L: 2:R: 6
# 2: L: 1:R: 30
# 1:
# 30:
# 6: L: 5:R: 7
# 5:
# 7:
#
# False
